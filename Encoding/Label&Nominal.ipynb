# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('titanic.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df=df.iloc[:,3:5 ]

# %%
df.head()
# Out:
#                                                 Name     Sex
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.iloc[:,0:1], df.iloc[:,-1], test_size=0.2, random_state=0)

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
X_train
# Out:
#                                                 Name
# 140                    Boulos, Mrs. Joseph (Sultana)
# 439           Kvillner, Mr. Johan Henrik Johannesson
# 817                               Mallet, Mr. Albert
# 378                              Betros, Mr. Tannous
# 491                              Windelov, Mr. Einar
# ..                                               ...
# 835                      Compton, Miss. Sara Rebecca
# 192  Andersen-Jensen, Miss. Carla Christine Nielsine
# 629                         O'Connell, Mr. Patrick D
# 559     de Messemaeker, Mrs. Guillaume Joseph (Emma)
# 684                Brown, Mr. Thomas William Solomon
#
# [712 rows x 1 columns]

# %%
oe=OrdinalEncoder(categories=[['long','short']])
//wrong dataset is used for the label encoding
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 2
#       1 oe=OrdinalEncoder(categories=[['long','short']])
# ----> 2 oe.fit(X_train)
#
# File c:\Users\karan\anaconda3\Lib\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\karan\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:1515, in OrdinalEncoder.fit(self, X, y)
#    1508     raise TypeError(
#    1509         "unknown_value should only be set when "
#    1510         "handle_unknown is 'use_encoded_value', "
# ...
