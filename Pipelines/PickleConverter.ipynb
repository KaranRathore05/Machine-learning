# %%
import pickle
import numpy as np
ohe_embarked=pickle.load(open('ohe_embarked.pkl','rb'))
clf=pickle.load(open('titanic_model.pkl','rb'))

# %%
test_input=np.array([[3,1,22.0,1,0,7.25,'S']]).reshape(1,7)

# %%
test_input
# Out:
# array([['3', '1', '22.0', '1', '0', '7.25', 'S']], dtype='<U32')

# %%
test_input_embarked=ohe_embarked.transform(test_input[:,6].reshape(1,1)).toarray()

# %%
same as pipeline
